# %%
import pandas as pd

# %% [markdown]
# #Welcome to PandasPizzeria

# %% [markdown]
# Welcome to the team! Here at PandasPizzeria your role includes finding data your coworker requests. Let me first explain how our system is set up. Below you can find a schema for our database.

# %% [markdown]
# ![image.png]()![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's review each of the 5 dataframes individually.

# %%
card_payments = pd.read_csv("card_payments.csv", header=0, index_col= 'card_id')
customers = pd.read_csv("customers.csv", header=0, index_col= 'customer_id')
orders = pd.read_csv("orders.csv", header=0, index_col= 'order_id')
pizza = pd.read_csv("pizza.csv", header=0, index_col= 'pizza_id')
toppings = pd.read_csv("toppings.csv", header=0, index_col= 'toppings_id')

# %% [markdown]
# The card_payments dataframe contains the payment information for all of our customers.

# %%
card_payments.head(3)

# %% [markdown]
# The customers dataframe contains all of our customers information

# %%
customers.head(3)

# %% [markdown]
# The orders dataframe contains the time and customer for each order

# %%
orders.head(3)

# %% [markdown]
# The pizza dataframe contains the information for each pizza type

# %%
pizza.head(3)

# %% [markdown]
# And finally the toppings dataframe contains all of the possible topping combinations. Columns labled with a 0 means no topping and those labled with a 1 mean one serving of the topping.

# %%
toppings.head(3)

# %% [markdown]
# Now that you're familiar with the layout, let's get started.

# %% [markdown]
# # Exercise

# %% [markdown]
# Our database contains all of our sales from today. As our new team member, you will be responsible for getting us the necessary information from the database. Although it is the end of the day for PandasPizzeria, it'll be the start for our data analysis team. Here's some information you'll need to know:
#
# - Every day this location fully stocks products so that way there are **75 units of each topping** before daily sales.
#
# We need you to find:
#
# - The **current stock** of toppings, **after all pizzas in the pizzas dataframe has been sold**.
#
# Create a new dataframe to display the current stock of toppings after pizza sales.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For our next order we will not fully restock some of the least sold items. Please find the percentage of times each topping was ordered in our database organized from greatest to least.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The payment team needs to know the credit card number and card type for all customers who ordered medium size pizzas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We are removing stuffed crust from our menu and need to issue a refund to any customer who ordered it. Please create a dataframe with the customer_id, full name, phone number, and address for those that meet the criteria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The kitchen needs to know what are the sizes and toppings on the pizzas  for order_id 25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The delivery people lost the address for their order. We only know that the order was made at 16:41:57. Please find the customer's name and address

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There is are new staff members in the kitchen today so we need to check the pizzas for orders made between 12pm to 3 pm. Please list the order number, size, and toppings for each pizza.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To finish up, we need to charge the cards for each customer now. First please calculate the total for each order and add it to the orders table. Here is the breakdown to calculate the prices:
#
#     1. Small size is 12.50
#     2. Medium size is 14.00
#     3. Large size is 15.50
#     4. Each topping is a .75 cents addition
#     5. Stuffed crust is a 1.00 addition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The company wants to adjust prices. Please find the average price for each size of pizza sold.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Discover is charging us too high of a processing fee to accept their cards, so we will no longer be accepting discover. Please find the customer name, phone number, and how much money was spent for each person who meets this criteria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Before we end the day, we have to send out coupons to customers who are in the top 50% for sales. Please create a dataframe with the customer id, name, phone number, and address for anyone who meets this criteria, listed from highest spender to lowest

# %% [markdown]
# ![image.png](data:image/png;base64,...)
